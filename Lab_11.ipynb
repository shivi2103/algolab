# %% [markdown]
# <a href="https://colab.research.google.com/github/shivi2103/algolab/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost

        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities

# %%
def tsp(graph, n, start=0):
    dp = [[None]*n for _ in range(1<<n)]

    def solve(mask, pos):
        if mask == (1<<n)-1:
            return graph[pos][start]
        if dp[mask][pos] is not None:
            return dp[mask][pos]

        ans = sys.maxsize
        for city in range(n):
            if not mask & (1<<city):
                ans = min(ans, graph[pos][city] + solve(mask | (1<<city), city))
        dp[mask][pos] = ans
        return ans

    return solve(1<<start, start)
n = int(input("Enter number of cities: "))
print("Enter distance matrix:")
graph = [list(map(int, input().split())) for _ in range(n)]
cost = tsp(graph, n)
print("Minimum travel cost:", cost)
# Out:
# Enter number of cities: 4
# Enter distance matrix:
# 0 10 15 20
# 10 0 35 25
# 15 35 0 30
# 20 25 30 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10988/3912383136.py in <cell line: 0>()
#      19 print("Enter distance matrix:")
#      20 graph = [list(map(int, input().split())) for _ in range(n)]
# ---> 21 cost = tsp(graph, n)
#      22 print("Minimum travel cost:", cost)
#
# /tmp/ipykernel_10988/3912383136.py in tsp(graph, n, start)
#      15         return ans
#      16
# ---> 17     return solve(1<<start, start)
#      18 n = int(input("Enter number of cities: "))
#      19 print("Enter distance matrix:")
#
# /tmp/ipykernel_10988/3912383136.py in solve(mask, pos)
#       8             return dp[mask][pos]
#       9
# ---> 10         ans = sys.maxsize
#      11         for city in range(n):
#      12             if not mask & (1<<city):
#
# NameError: name 'sys' is not defined
